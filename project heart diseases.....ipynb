# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
heart = pd.read_csv("heart_disease_data.csv")

# %%
heart
# Out:
#       age  sex  chest pain type  resting bp s  cholesterol  \
# 0      55    1                4           140          268
# 1      46    1                3           150          163
# 2      32    1                4           118          529
# 3      35    0                4           140          167
# 4      52    1                2           140          100
# ...   ...  ...              ...           ...          ...
# 1384   57    0                0           140          241
# 1385   45    1                3           110          264
# 1386   68    1                0           144          193
# 1387   57    1                0           130          131
# 1388   57    0                1           130          236
#
#       fasting blood sugar  resting ecg  max heart rate  exercise angina  \
# 0                       0            0             128                1
# 1                       0            0             116                0
# ...

# %%
heart.head()
# Out:
#    age  sex  chest pain type  resting bp s  cholesterol  fasting blood sugar  \
# 0   55    1                4           140          268                    0
# 1   46    1                3           150          163                    0
# 2   32    1                4           118          529                    0
# 3   35    0                4           140          167                    0
# 4   52    1                2           140          100                    0
#
#    resting ecg  max heart rate  exercise angina  oldpeak  ST slope  target
# 0            0             128                1      1.5         2       1
# 1            0             116                0      0.0         1       0
# 2            0             130                0      0.0         2       1
# 3            0             150                0      0.0         1       0
# 4            0             138                1      0.0         1       0

# %%
heart.shape
# Out:
# (1389, 12)

# %% [markdown]
# # Data Cleaning & Preprocessing

# %%
heart.isna().sum()
# Out:
# age                    0
# sex                    0
# chest pain type        0
# resting bp s           0
# cholesterol            0
# fasting blood sugar    0
# resting ecg            0
# max heart rate         0
# exercise angina        0
# oldpeak                0
# ST slope               0
# target                 0
# dtype: int64

# %%
heart.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1389 entries, 0 to 1388
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   age                  1389 non-null   int64
#  1   sex                  1389 non-null   int64
#  2   chest pain type      1389 non-null   int64
#  3   resting bp s         1389 non-null   int64
#  4   cholesterol          1389 non-null   int64
#  5   fasting blood sugar  1389 non-null   int64
#  6   resting ecg          1389 non-null   int64
#  7   max heart rate       1389 non-null   int64
#  8   exercise angina      1389 non-null   int64
#  9   oldpeak              1389 non-null   float64
#  10  ST slope             1389 non-null   int64
#  11  target               1389 non-null   int64
# dtypes: float64(1), int64(11)
# memory usage: 130.3 KB

# %%
#statistics descriptive of the data set
heart.describe()
# Out:
#                age          sex  chest pain type  resting bp s  cholesterol  \
# count  1389.000000  1389.000000      1389.000000   1389.000000  1389.000000
# mean     53.511879     0.733621         2.714903    131.930886   220.484521
# std       9.267675     0.442224         1.334831     18.190937    92.331796
# min      28.000000     0.000000         0.000000      0.000000     0.000000
# 25%      47.000000     0.000000         2.000000    120.000000   198.000000
# 50%      54.000000     1.000000         3.000000    130.000000   233.000000
# 75%      60.000000     1.000000         4.000000    140.000000   271.000000
# max      77.000000     1.000000         4.000000    200.000000   603.000000
#
#        fasting blood sugar  resting ecg  max heart rate  exercise angina  \
# count          1389.000000  1389.000000     1389.000000      1389.000000
# mean              0.178546     0.655148      142.770338         0.366451
# ...

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %%
dt_corr = heart.corr()

plt.figure(figsize=(10, 8))
sns.heatmap(dt_corr, annot=True, cmap='ocean')
plt.tight_layout()
plt.show()

# %%
labels=['Male','Female']
# Size for figures

plt.figure(figsize= (6,4))
plt.title('Sex (Gender) Distribution')
#plot for pie chart 

plt.plot(1,2,1)
plt.title('Pie Chart')
plt.pie(heart['sex'].value_counts(),labels=labels, autopct='%.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x15ae6ddd850>,
# ...
#  [Text(-0.7367828979635611, 0.816793095752172, 'Male'),
#   Text(0.736782897963561, -0.8167930957521721, 'Female')],
#  [Text(-0.40188158070739693, 0.44552350677391195, '73.36%'),
#   Text(0.4018815807073969, -0.445523506773912, '26.64%')])

# %%
# above picchart and Histogram chart represents sex  Distribution among Gender 1.Female and 2.Male with percentages

# %%
labels=['< 120 mg/dl', '> 120 mg/dl']
order=heart['fasting blood sugar'].value_counts().index

# Size for both figures
plt.figure(figsize= (16,8))
plt.suptitle('Fasting Blood Sugar Distribution on male and female')

# Subplot for 1 Pie Chart
plt.subplot(1,2,1)
plt.title('Pie Chart')
plt.pie(heart['fasting blood sugar'] .value_counts(),labels=labels, autopct='%.2f%%')
centre=plt.Circle((0, 0), 0.35, fc='white')
plt.gcf().gca().add_artist(centre)

#Subplot for  2 Histogram
countplt = plt.subplot(1,2,2)
plt.title('Histogram')
ax= sns.countplot(x='fasting blood sugar',data=heart,order=order)
plt.xlabel('fasting blood sugar')
plt.ylabel('Total')
countplt
# Out:
# <Axes: title={'center': 'Histogram'}, xlabel='fasting blood sugar', ylabel='Total'>

# %%
#above picchart and Histogram chart represents Fasting BLood Sugar   Distribution among Gender 1.Female and 2.Male with percentages

# %%
x=heart.hist(figsize=(20,20))

# %%
X = heart.drop('target',axis=1)

# %%
y = heart['target']

# %%
from sklearn.model_selection import train_test_split
X_train,x_test,Y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
##model builiding on Logisticregression 
from sklearn.linear_model import LogisticRegression
logreg=LogisticRegression()

# %%
logreg.fit(X_train,Y_train)
# Out:
# LogisticRegression()

# %%
logreg.score(x_test,y_test)
# Out:
# 0.7302158273381295

# %%
pred =logreg.predict(x_test)

# %%
pred =logreg.predict(x_test)
from sklearn.metrics import confusion_matrix,accuracy_score
acc_logreg=accuracy_score(y_test,pred)*100

# %%
tab1=confusion_matrix(y_test,pred)
tab1
# Out:
# array([[108,  22,   0,   0,   0],
#        [ 37,  95,   0,   0,   0],
#        [  5,   3,   0,   0,   0],
#        [  6,   0,   0,   0,   0],
#        [  2,   0,   0,   0,   0]], dtype=int64)

# %%
tab1.diagonal().sum()/tab1.sum()*100
# Out:
# 73.02158273381295

# %% [markdown]
# # model builiding on Decisiontree classifler

# %%
from sklearn.tree import DecisionTreeClassifier
dtc=DecisionTreeClassifier()

# %%
dtc
# Out:
# DecisionTreeClassifier()

# %%
dtc.fit(X_train,Y_train)
# Out:
# DecisionTreeClassifier()

# %%
dtc.score(x_test,y_test)
# Out:
# 0.8237410071942446

# %%
from sklearn.tree import DecisionTreeClassifier
model1=DecisionTreeClassifier(criterion='gini')

# %%
model1.fit(X_train,Y_train)
# Out:
# DecisionTreeClassifier()

# %%
model1.score(x_test,y_test)
# Out:
# 0.8201438848920863

# %%
from sklearn.tree import DecisionTreeClassifier
model2=DecisionTreeClassifier(criterion='gini')

# %%
model2.fit(X_train,Y_train)
# Out:
# DecisionTreeClassifier()

# %%
model2.score(x_test,y_test)
# Out:
# 0.8237410071942446

# %% [markdown]
# # model builiding ob Randomforest classifier

# %%
from sklearn.ensemble import RandomForestClassifier
rfc=RandomForestClassifier()
rfc.fit(X_train,Y_train)
# Out:
# RandomForestClassifier()

# %%
rfc.score(x_test,y_test)
# Out:
# 0.8489208633093526

# %%
from sklearn.model_selection import GridSearchCV

# %%
search_dict_rfc= {"criterion":["gini","entropy"],
                 "n_estimators":(50,75,100,125,150)}

# %%
dt_GridSearchCV = GridSearchCV(rfc ,  param_grid =search_dict_rfc )

# %%
dt_GridSearchCV.fit(X_train,Y_train)
# Out:
# GridSearchCV(estimator=RandomForestClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'n_estimators': (50, 75, 100, 125, 150)})

# %%
dt_GridSearchCV.best_params_
# Out:
# {'criterion': 'entropy', 'n_estimators': 150}

# %% [markdown]
# # model builiding on Gradientboosting Classifier

# %%
from sklearn.ensemble import GradientBoostingClassifier
gcb=GradientBoostingClassifier()

# %%
gcb.fit(X_train,Y_train)
# Out:
# GradientBoostingClassifier()

# %%
gcb.score(x_test,y_test)
# Out:
# 0.802158273381295

# %% [markdown]
# # model builiding on SVR Classifier

# %%
from sklearn.svm import SVC
svc=SVC()

# %%
svc.fit(X_train,Y_train)
# Out:
# SVC()

# %%
svc.score(x_test,y_test)
# Out:
# 0.6223021582733813

# %% [markdown]
# # model builiding on KNeighnors classifier

# %%
from sklearn.neighbors import KNeighborsClassifier
KN = KNeighborsClassifier()
KN.fit(X_train,Y_train)
# Out:
# KNeighborsClassifier()

# %%
KN.score(x_test,y_test)
# Out:
# 0.6258992805755396

# %%
from sklearn.ensemble import AdaBoostClassifier

# %%
adamodel=AdaBoostClassifier()

# %%
adamodel.fit(X_train,Y_train)
# Out:
# AdaBoostClassifier()

# %%
adamodel.score(x_test,y_test)
# Out:
# 0.38489208633093525

# %%
dt1= DecisionTreeClassifier()

# %%
rfc1=RandomForestClassifier()

# %%
svc1=SVC()

# %%
knn1=KNeighborsClassifier()

# %%
ada1=AdaBoostClassifier()

# %%
gbc=GradientBoostingClassifier()

# %%
lr1=LogisticRegression()

# %%
model=[dt1,rfc1,svc1,knn1,ada1,gbc,lr1]

# %%
for i in model:
    print(i) 
    i.fit(X_train,Y_train) 
    i.score(x_test,y_test)
    s=i.score(x_test,y_test)
    print(s)
# Out:
# DecisionTreeClassifier()
# 0.8201438848920863
# RandomForestClassifier()
# 0.841726618705036
# SVC()
# 0.6223021582733813
# KNeighborsClassifier()
# 0.6258992805755396
# AdaBoostClassifier()
# 0.38489208633093525
# GradientBoostingClassifier()
# 0.802158273381295
# LogisticRegression()
# 0.7302158273381295

# %%
score_list=[]
for i in model:
    print(i) 
    i.fit(X_train,Y_train) 
    i.score(x_test,y_test)
    s=i.score(x_test,y_test)
    score_list.append(s)
    print(score_list)
# Out:
# DecisionTreeClassifier()
# [0.8309352517985612]
# RandomForestClassifier()
# [0.8309352517985612, 0.8453237410071942]
# SVC()
# [0.8309352517985612, 0.8453237410071942, 0.6223021582733813]
# KNeighborsClassifier()
# [0.8309352517985612, 0.8453237410071942, 0.6223021582733813, 0.6258992805755396]
# AdaBoostClassifier()
# [0.8309352517985612, 0.8453237410071942, 0.6223021582733813, 0.6258992805755396, 0.38489208633093525]
# GradientBoostingClassifier()
# [0.8309352517985612, 0.8453237410071942, 0.6223021582733813, 0.6258992805755396, 0.38489208633093525, 0.802158273381295]
# LogisticRegression()
# [0.8309352517985612, 0.8453237410071942, 0.6223021582733813, 0.6258992805755396, 0.38489208633093525, 0.802158273381295, 0.7302158273381295]

# %%
score_list=[]
for i in model: 
    i.fit(X_train,Y_train) 
    s=i.score(x_test,y_test)
    score_list.append(s)
r=max(score_list)
print(r)
I=score_list.index(r)
print(I)
model[I]
# Out:
# 0.8489208633093526
# 1
# RandomForestClassifier()
